# %%
#  _       __                 _            
# | |     / /___ __________  (_)___  ____ _
# | | /| / / __ `/ ___/ __ \/ / __ \/ __ `/
# | |/ |/ / /_/ / /  / / / / / / / / /_/ / 
# |__/|__/\__,_/_/  /_/ /_/_/_/ /_/\__, /  
#                                 /____/   
# set up a new python enviroment with python 3.8 and use it to run this code.
# it will install all required packages
# some code is based on the tutorial below:
# https://www.sliceofexperiments.com/p/an-actually-runnable-march-2023-tutorial


#run the following commands in terminal to set up the env. 
# conda create -n dsan_rl python=3.8
#conda activate dsan_rl
# Out:
# Collecting ray
#   Downloading ray-2.10.0-cp38-cp38-manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting click>=7.0 (from ray)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting filelock (from ray)
#   Downloading filelock-3.13.4-py3-none-any.whl.metadata (2.8 kB)
# Collecting jsonschema (from ray)
#   Using cached jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray)
#   Downloading msgpack-1.0.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: packaging in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ray) (24.0)
# Collecting protobuf!=3.19.5,>=3.15.3 (from ray)
#   Downloading protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting pyyaml (from ray)
#   Downloading PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting aiosignal (from ray)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist (from ray)
#   Downloading frozenlist-1.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting requests (from ray)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting attrs>=22.2.0 (from jsonschema->ray)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting importlib-resources>=1.4.0 (from jsonschema->ray)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->ray)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema->ray)
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting referencing>=0.28.4 (from jsonschema->ray)
#   Using cached referencing-0.34.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->ray)
#   Downloading rpds_py-0.18.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests->ray)
#   Downloading charset_normalizer-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->ray)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->ray)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->ray)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: zipp>=3.1.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema->ray) (3.17.0)
# Downloading ray-2.10.0-cp38-cp38-manylinux2014_x86_64.whl (65.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 MB 59.3 MB/s eta 0:00:00:00:010:01m
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading msgpack-1.0.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 kB 38.8 MB/s eta 0:00:00
# Downloading protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 34.1 MB/s eta 0:00:00
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 30.8 MB/s eta 0:00:00
# Downloading filelock-3.13.4-py3-none-any.whl (11 kB)
# Using cached jsonschema-4.21.1-py3-none-any.whl (85 kB)
# Downloading PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (736 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 736.6/736.6 kB 64.0 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 9.9 MB/s eta 0:00:00
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 23.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 23.9 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 10.7 MB/s eta 0:00:00
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Using cached referencing-0.34.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.6 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 17.6 MB/s eta 0:00:00
# Installing collected packages: urllib3, rpds-py, pyyaml, protobuf, pkgutil-resolve-name, msgpack, importlib-resources, idna, frozenlist, filelock, click, charset-normalizer, certifi, attrs, requests, referencing, aiosignal, jsonschema-specifications, jsonschema, ray
# Successfully installed aiosignal-1.3.1 attrs-23.2.0 certifi-2024.2.2 charset-normalizer-3.3.2 click-8.1.7 filelock-3.13.4 frozenlist-1.4.1 idna-3.7 importlib-resources-6.4.0 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 msgpack-1.0.8 pkgutil-resolve-name-1.3.10 protobuf-5.26.1 pyyaml-6.0.1 ray-2.10.0 referencing-0.34.0 requests-2.31.0 rpds-py-0.18.0 urllib3-2.2.1
# Collecting gymnasium
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.21.0 (from gymnasium)
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium)
#   Using cached cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from gymnasium) (4.11.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from gymnasium) (7.1.0)
# Requirement already satisfied: zipp>=0.5 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.17.0)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Using cached cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 49.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: farama-notifications, numpy, cloudpickle, gymnasium
# Successfully installed cloudpickle-3.0.0 farama-notifications-0.0.4 gymnasium-0.29.1 numpy-1.24.4
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipywidgets) (8.12.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: backcall in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pickleshare in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: typing-extensions in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (4.11.0)
# Requirement already satisfied: pexpect>4.3 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Using cached ipywidgets-8.1.2-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
# Using cached widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.2 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10
# Collecting dm-tree
#   Downloading dm_tree-0.1.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Downloading dm_tree-0.1.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (152 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: dm-tree
# Successfully installed dm-tree-0.1.8
# Collecting pyarrow
#   Downloading pyarrow-15.0.2-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<2,>=1.16.6 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from pyarrow) (1.24.4)
# Downloading pyarrow-15.0.2-cp38-cp38-manylinux_2_28_x86_64.whl (38.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 73.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pyarrow
# Successfully installed pyarrow-15.0.2
# Collecting typer
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: click>=8.0.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from typer) (8.1.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from typer) (4.11.0)
# Collecting shellingham>=1.3.0 (from typer)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/emdapkus/miniconda3/envs/dsan_rl/lib/python3.8/site-packages (from rich>=10.11.0->typer) (2.17.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached typer-0.12.3-py3-none-any.whl (47 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: shellingham, mdurl, markdown-it-py, rich, typer
# Successfully installed markdown-it-py-3.0.0 mdurl-0.1.2 rich-13.7.1 shellingham-1.5.4 typer-0.12.3

# %%
import gymnasium as gym
from gymnasium.wrappers import FlattenObservation

# %%
import gymnasium as gym
env = gym.make("LunarLander-v2", render_mode="human")
observation, info = env.reset()

for _ in range(100):
    action = env.action_space.sample()  # agent policy that uses the observation and info
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()

env.close()

# %%
env = gym.make("LunarLander-v2")
print(env.observation_space.shape)
print(env.action_space)

wrapped_env = FlattenObservation(env)
print(wrapped_env.observation_space)
print(wrapped_env.observation_space.shape)
# Out:
# (8,)
# Discrete(4)
# Box([-1.5       -1.5       -5.        -5.        -3.1415927 -5.
#  -0.        -0.       ], [1.5       1.5       5.        5.        3.1415927 5.        1.
#  1.       ], (8,), float32)
# (8,)

# %%
print(wrapped_env)
print(wrapped_env.unwrapped)
# Out:
# <FlattenObservation<TimeLimit<OrderEnforcing<PassiveEnvChecker<LunarLander<LunarLander-v2>>>>>>
# <LunarLander<LunarLander-v2>>

# %%
from __future__ import annotations

from collections import defaultdict

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.patches import Patch
from tqdm import tqdm

import gymnasium as gym

# %%
env = gym.make("LunarLander-v2")

# %%
done = False
observation, info = env.reset()

print(observation)
print(info)
# Out:
# [ 0.00423479  1.4111595   0.42892367  0.01062951 -0.00490029 -0.09715758
#   0.          0.        ]
# {}

# %%
class LunarLader:
    def __init__(
            self,
            learning_rate,#float
            init_eps,#float
            decay_eps,#float
            final_eps,#float
            discount = 0.95#float
    ):
        # self.q_values = defaultdict(lambda: np.zeros(env.action.space.n))
        # self.q_values = defaultdict(lambda: np.zeros(env.action_space.n))
        self.q_values = defaultdict(lambda: np.zeros(env.action_space.n))

        self.lr = learning_rate
        self.discount = discount
        self.eps = init_eps
        self.decay_eps = decay_eps
        self.final_eps = final_eps

        self.training_error = []

    def get_action(self, obs):
        if np.random.random() < self.eps:
            return env.action_space.sample()
        else:
            return int(np.argmax(self.q_values[obs]))
        
    # def get_action(self, obs):
    #     if np.random.random() < self.eps:
    #         return env.action_space.sample()
    #     else:
    #         return int(np.argmax(self.q_values[obs]))

        
    # def update(
    #         self,
    #         obs,
    #         action,
    #         reward,
    #         terminated,
    #         next_obs
    # ):
    #     future_q_value = (not terminated) * np.max(self.q_values[tuple(next_obs)])
    #     temporal_difference = (
    #         reward + self.discount * future_q_value - self.q_values[obs][action]
    #     )

    #     self.q_values[obs][action] = (self.q_values + self.lr * temporal_difference)

    #     self.training_error.append(temporal_difference)

    def update(self, obs, action, reward, terminated, next_obs):
        future_q_value = (not terminated) * np.max(self.q_values[tuple(next_obs)])
        temporal_difference = (
            reward + self.discount * future_q_value - self.q_values[obs][action]
    )

        self.q_values[obs][action] += self.lr * temporal_difference  # Fix this line

        self.training_error.append(temporal_difference)


    def decay_epsilon(self):
        self.eps = max(self.final_eps, self.eps - self.decay_eps)

# %%
learning_rate = 0.01
n_episodes = 100_000
start_epsilon = 1.0
epsilon_decay = start_epsilon / (n_episodes / 2)  # reduce the exploration over time
final_epsilon = 0.1

agent = LunarLader(
    learning_rate=learning_rate,
    init_eps=start_epsilon,
    decay_eps=epsilon_decay,
    final_eps=final_epsilon,
)

# %%
env = gym.wrappers.RecordEpisodeStatistics(env, deque_size=n_episodes)
for episode in tqdm(range(n_episodes)):
    obs, info = env.reset()
    done = False

    # play one episode
    while not done:
        action = agent.get_action(obs)
        next_obs, reward, terminated, truncated, info = env.step(action)

        # update the agent
        agent.update(obs, action, reward, terminated, next_obs)

        # update if the environment is done and the current obs
        done = terminated or truncated
        obs = next_obs

    agent.decay_epsilon()
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 12
#       9 next_obs, reward, terminated, truncated, info = env.step(action)
#      11 # update the agent
# ---> 12 agent.update(obs, action, reward, terminated, next_obs)
#      14 # update if the environment is done and the current obs
#      15 done = terminated or truncated
#
# Cell In[4], line 45, in LunarLader.update(self, obs, action, reward, terminated, next_obs)
#      35 def update(
#      36         self,
#      37         obs,
#    (...)
#      41         next_obs
#      42 ):
#      43     future_q_value = (not terminated) * np.max(self.q_values[tuple(next_obs)])
#      44     temporal_difference = (
# ---> 45         reward + self.discount * future_q_value - self.q_values[obs][action]
#      46     )
#      48     self.q_values[obs][action] = (self.q_values + self.lr * temporal_difference)
#      50     self.training_error.append(temporal_difference)
#
# TypeError: unhashable type: 'numpy.ndarray'
